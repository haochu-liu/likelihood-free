# %% [markdown]
# # Plots for the TARP test

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load data

# %%
model_names = ['NPE']
sim_budgets = ['200', '500', '1000', '2000', '5000', '10000', '50000']

# %%
npe_tarp = np.full((2, 7, 10), np.nan)
for i in range(1, 11):
    load_path = f'../data/benchmark_tarp/npe_tarp{i}.csv'
    npe_tarp_i = np.loadtxt(load_path, delimiter=',')
    npe_tarp[:, :, i-1] = npe_tarp_i

# %%
fig, ax = plt.subplots(1, 1, figsize=(5, 6), sharey=True)
fig.suptitle('TARP P-Values', fontsize=14, fontweight='bold', y=1.05)

x_base = np.arange(len(sim_budgets))
x = np.repeat(x_base, 10)
offsets = [-0.09, 0.09]

y1 = npe_tarp[1, :, :].flatten()

ax.scatter(x + offsets[0], y1, marker='x', color='blue', alpha=0.5)

ax.hlines(
    y=0.05,
    xmin=x_base[0] - 0.35,
    xmax=x_base[-1] + 0.35,
    color='red',
    linestyle='--',
    linewidth=1,
    label='Significance level (0.05)'
)

ax.set_title(model_names[0], fontsize=12, pad=10)
ax.set_xticks(x_base)
ax.set_xticklabels(sim_budgets, rotation=90)
ax.set_xlim(x_base[0] - 0.5, x_base[-1] + 0.5)

ax.grid(axis='y', linestyle='-', color='lightgray', alpha=0.8)

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_color('lightgray')

ax.tick_params(axis='y', length=0)

ax.set_ylabel('p-value', fontsize=12)
ax.legend(loc='upper left', fontsize=10, frameon=False)
fig.text(0.5, -0.05, 'Number of Simulations', ha='center', va='center', fontsize=12)
plt.ylim(0, 1.2)
plt.subplots_adjust(wspace=0.05, bottom=0.2)
plt.show()

# %%
fig, ax = plt.subplots(1, 1, figsize=(5, 6), sharey=True)
fig.suptitle('TARP Area to diagonal line', fontsize=14, fontweight='bold', y=1.05)

x_base = np.arange(len(sim_budgets))
x = np.repeat(x_base, 10)
offsets = [-0.09, 0.09]

y1 = npe_tarp[0, :, :].flatten()

ax.scatter(x + offsets[0], y1, marker='x', color='blue', alpha=0.5)

ax.hlines(
    y=0,
    xmin=x_base[0] - 0.35,
    xmax=x_base[-1] + 0.35,
    color='red',
    linestyle='--',
    linewidth=1,
    label='Area = 0 (Perfect Calibration)'
)

ax.set_title(model_names[0], fontsize=12, pad=10)
ax.set_xticks(x_base)
ax.set_xticklabels(sim_budgets, rotation=90)
ax.set_xlim(x_base[0] - 0.5, x_base[-1] + 0.5)

ax.grid(axis='y', linestyle='-', color='lightgray', alpha=0.8)

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_color('lightgray')

ax.tick_params(axis='y', length=0)

ax.set_ylabel('p-value', fontsize=12)
ax.legend(loc='upper left', fontsize=10, frameon=False)
fig.text(0.5, -0.05, 'Number of Simulations', ha='center', va='center', fontsize=12)
plt.ylim(-0.1, 0.1)
plt.subplots_adjust(wspace=0.05, bottom=0.2)
plt.show()
