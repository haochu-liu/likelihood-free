# %% [markdown]
# # Posterior for Bacillus local recombination rate and mutation rate using SBI

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.collections import LineCollection
from matplotlib.lines import Line2D
import seaborn as sns
from Bio import Phylo
import torch
from torch.distributions import Uniform
import sbi
from sbi.utils.user_input_checks import MultipleIndependent
from sbi.inference import NPE_C
from sbi.analysis import plot_summary
import sys
sys.path.append('../pysimARG')
from discrete_uniform import DiscreteUniform

torch_device = "cpu"

# %% [markdown]
# ## Load simulation data
#
# Load staph gene data and clonal tree.

# %%
# Load phylo tree and convert to ClonalTree format
phylo_tree = Phylo.read("../data/bacillus/bacillus.nwk", "newick")
Phylo.draw_ascii(phylo_tree)
# Out:
#                                                                       ____ 1
#                                                                    __|
#                                                                  _|  |____ 4
#                                                                 | |
#                                                            _____| |_______ 12
#                                                           |     |
#                                                           |     |       __ 2
#                                           ________________|     |______|
#                                          |                |            |__ 11
#                                          |                |
#               ___________________________|                |_______________ 10
#              |                           |
#              |                           |                            ____ 3
#              |                           |             ______________|
#              |                           |____________|              |____ 9
#   ___________|                                        |
#  |           |                                        |___________________ 5
#  |           |
#  |           |                                                    ________ 6
# _|           |                                  _________________|
#  |           |_________________________________|                 |________ 7
#  |                                             |
#  |                                             |__________________________ 8
#  |
#  |_______________________________________________________________________ 13

# %%
x_obs_info_table = pd.read_csv("../data/bacillus/bacillus_block_info.csv", index_col=0)
x_obs_info_table.head()
# Out:
#          Gene_Length  Start_pos  End_pos  Alignment
# Gene_ID
# 0_0             5247      71581    76827       True
# 0_1             5246      76828    82073       True
# 1               4191      67350    71540       True
# 2               2175      28543    30717       True
# 3               2401     142577   144977       True

# %%
x_obs_df = pd.read_csv("../data/bacillus/bacillus_block_summary_stats.csv", header=None)
x_obs_np = x_obs_df.to_numpy()
x_obs_torch = torch.tensor(x_obs_np, device=torch_device)
x_obs_torch = x_obs_torch.to(torch.float32)
x_obs_torch.shape, x_obs_torch.dtype
# Out:
# (torch.Size([1277, 46]), torch.float32)

# %% [markdown]
# ### Delete observations with no signal

# %%
x_obs_info_table
# Out:
#          Gene_Length  Start_pos  End_pos  Alignment
# Gene_ID
# 0_0             5247      71581    76827       True
# 0_1             5246      76828    82073       True
# 1               4191      67350    71540       True
# 2               2175      28543    30717       True
# 3               2401     142577   144977       True
# ...              ...        ...      ...        ...
# 1214            1363    5190561  5191923       True
# 1215_0          5051    5217306  5222356       True
# 1215_1          5050    5222357  5227406       True
# 1216            6764    5175949  5182712       True
# 1217            3029    5194780  5197808       True
#
# [1277 rows x 4 columns]

# %%
too_large_length = np.where(x_obs_info_table['Gene_Length'] > 10000)[0]
too_large_length
# Out:
# array([], dtype=int64)

# %%
no_signal_id = np.where(x_obs_np[:, 33] == 0)[0]
no_signal_id.shape, no_signal_id[:10]
# Out:
# ((0,), array([], dtype=int64))

# %% [markdown]
# Ignore the observations that have too large gene length. But there is no observations with no signal.

# %% [markdown]
# ## Load simulation data

# %%
theta1 = np.loadtxt('../data/bacillus/ClonalOrigin_sim/change_theta/theta1.csv', delimiter=",")
x1 = np.loadtxt('../data/bacillus/ClonalOrigin_sim/change_theta/x1.csv', delimiter=",")

theta2 = np.loadtxt('../data/bacillus/ClonalOrigin_sim/change_theta/theta2.csv', delimiter=",")
x2 = np.loadtxt('../data/bacillus/ClonalOrigin_sim/change_theta/x2.csv', delimiter=",")

theta3 = np.loadtxt('../data/bacillus/ClonalOrigin_sim/change_theta/theta3.csv', delimiter=",")
x3 = np.loadtxt('../data/bacillus/ClonalOrigin_sim/change_theta/x3.csv', delimiter=",")

theta4 = np.loadtxt('../data/bacillus/ClonalOrigin_sim/change_theta/theta4.csv', delimiter=",")
x4 = np.loadtxt('../data/bacillus/ClonalOrigin_sim/change_theta/x4.csv', delimiter=",")

theta5 = np.loadtxt('../data/bacillus/ClonalOrigin_sim/change_theta/theta5.csv', delimiter=",")
x5 = np.loadtxt('../data/bacillus/ClonalOrigin_sim/change_theta/x5.csv', delimiter=",")

x = np.vstack([x1, x2, x3, x4, x5])
theta = np.vstack([theta1, theta2, theta3, theta4, theta5])

print(theta.shape, x.shape)
# Out:
# (50000, 3) (50000, 46)

# %%
theta = torch.tensor(theta, device=torch_device)
theta = theta.to(torch.float32)
theta_numpy = theta.cpu().numpy()

x = torch.tensor(x, device=torch_device)
x = x.to(torch.float32)
x_numpy = x.cpu().numpy()

# %% [markdown]
# ### Find out-of-range observations

# %%
ignore_indices = []
no_segregation = []
out_stats = dict()
for i in range(x_obs_torch.shape[0]):
    ignore_i = False
    out_index = []
    for j in range(46):
        max_j = torch.max(x[:, j])
        min_j = torch.min(x[:, j])
        obs_j = x_obs_torch[i, j]
        if obs_j < min_j or obs_j > max_j:
            ignore_i = True
            out_index.append(j)
        if j == 33 and obs_j == 0:
            no_segregation.append(i)
    if ignore_i or torch.isnan(x_obs_torch[i, :]).any():
        print(f"Observation {i} is outside the range of simulated data.")
        ignore_indices.append(i)
        out_stats[i] = out_index
# Out:
# Observation 121 is outside the range of simulated data.
# Observation 133 is outside the range of simulated data.
# Observation 179 is outside the range of simulated data.
# Observation 283 is outside the range of simulated data.
# Observation 1093 is outside the range of simulated data.
# Observation 1244 is outside the range of simulated data.
# Observation 1259 is outside the range of simulated data.
# Observation 1269 is outside the range of simulated data.

# %%
len(ignore_indices), len(no_segregation), len(out_stats)
# Out:
# (8, 0, 8)

# %%
out_index_all = []
for i in range(len(ignore_indices)):
    idx = ignore_indices[i]
    out_index_all += out_stats[idx]

# %%
from collections import Counter

integer_counts = Counter(out_index_all)

# %%
for i in range(32):
    print(f"Index {i}: {integer_counts[i]}")
# Out:
# Index 0: 0
# Index 1: 0
# Index 2: 0
# Index 3: 0
# Index 4: 0
# Index 5: 0
# Index 6: 0
# Index 7: 0
# Index 8: 1
# Index 9: 7
# Index 10: 0
# Index 11: 0
# Index 12: 0
# Index 13: 0
# Index 14: 0
# Index 15: 0
# Index 16: 0
# Index 17: 0
# Index 18: 0
# Index 19: 0
# Index 20: 0
# Index 21: 0
# Index 22: 0
# Index 23: 0
# Index 24: 0
# Index 25: 0
# Index 26: 0
# Index 27: 0
# Index 28: 0
# Index 29: 0
# Index 30: 0
# Index 31: 0

# %%
for i in range(32, 46):
    print(f"Index {i}: {integer_counts[i]}")
# Out:
# Index 32: 0
# Index 33: 1
# Index 34: 0
# Index 35: 0
# Index 36: 0
# Index 37: 0
# Index 38: 0
# Index 39: 0
# Index 40: 0
# Index 41: 0
# Index 42: 0
# Index 43: 0
# Index 44: 0
# Index 45: 0

# %% [markdown]
# ## NPE

# %% [markdown]
# ### Create prior to pass range knowledge to NPE

# %%
prior_rho = Uniform(low=torch.tensor([0.0]), high=torch.tensor([0.2]))
prior_theta = Uniform(low=torch.tensor([0.0]), high=torch.tensor([0.1]))
prior_L = DiscreteUniform(low=torch.tensor([100.0]), high=torch.tensor([10000.0]))

prior = MultipleIndependent(
    dists=[prior_rho, prior_theta, prior_L],
    validate_args=False,
    device=torch_device
)

# %%
seed = 100
num_posterior_samples=1000
learning_rate = 0.0005

inference = NPE_C(prior=prior, density_estimator="nsf", device=torch_device)
torch.manual_seed(seed)
np.random.seed(seed)

# %%
density_estimator = inference.append_simulations(theta, x).train(
    max_num_epochs=500, learning_rate=learning_rate
)
posterior = inference.build_posterior(density_estimator)
# Out:
# c:\Users\u2008181\likelihood-free\sbi_env\Lib\site-packages\sbi\inference\trainers\npe\npe_base.py:196: UserWarning: Data has extreme outliers in dimension(s) [8, 9, 10, 11, 12, 13, 14, 15, 24, 25, 26, 27, 28, 29, 30, 31, 36, 38, 39, 41, 42, 43, 44] (beyond 10.0x IQR from quartiles). This may cause precision loss during z-scoring, where distinct values become indistinguishable. Consider removing outliers from your data or setting `z_score_x='none'` (though this may affect training).
#   warn_if_invalid_for_zscoring(x)
# WARNING:root:Found 49 NaN simulations and 0 Inf simulations. They will be excluded from training.
#  Neural network successfully converged after 110 epochs.

# %%
fig, axes = plot_summary(
    inference, 
    tags=["training_loss", "validation_loss"], 
    figsize=(8, 4)
)
plt.title("Training and Validation Loss")
plt.show()
# Out:
# WARNING:sbi.analysis.tensorboard_output:For an interactive, detailed view of the summary, launch tensorboard  with 'tensorboard --logdir=c:\Users\u2008181\likelihood-free\python\sbi-logs\NPE_C\2026-07-10T10_51_30.940967' from a terminal on your machine, visit http://127.0.0.1:6006 afterwards. Requires port forwarding if tensorboard runs on a remote machine, as e.g. https://stackoverflow.com/a/42445070/7770835 explains.
#
# WARNING:sbi.analysis.tensorboard_output:Valid tags are: ['best_validation_loss', 'epoch_durations_sec', 'epochs_trained', 'training_loss', 'validation_loss'].

# %% [markdown]
# ### Save the trained NPE

# %%
save_path = "../data/bacillus/trained_npe_density_estimator.pt"

torch.save(
    {
        "density_estimator": density_estimator,
        "prior": prior,
        "sbi_version": sbi.__version__,
        "learning_rate": learning_rate,
        "max_num_epochs": 500,
    },
    save_path,
)

# %% [markdown]
# ### Plug in observation data to get posterior

# %%
theta_post = np.full((x_obs_torch.shape[0], num_posterior_samples, 3), np.nan)
theta_post.shape
# Out:
# (1277, 1000, 3)

# %%
for i in range(x_obs_torch.shape[0]):
    # if i in ignore_indices:
    #     continue

    theta_post_torch = posterior.sample((num_posterior_samples,), x=x_obs_torch[i, :],
                                        show_progress_bars=False, reject_outside_prior=False)
    theta_post[i, :, :] = theta_post_torch.cpu().detach().numpy()
# Out:
# C:\Users\u2008181\AppData\Local\Temp\ipykernel_27304\3238161204.py:5: UserWarning: 19.4% of samples drawn with reject_outside_prior=False lie outside the prior support. This may lead to incorrect inference.
#   theta_post_torch = posterior.sample((num_posterior_samples,), x=x_obs_torch[i, :],
# C:\Users\u2008181\AppData\Local\Temp\ipykernel_27304\3238161204.py:5: UserWarning: 8.6% of samples drawn with reject_outside_prior=False lie outside the prior support. This may lead to incorrect inference.
#   theta_post_torch = posterior.sample((num_posterior_samples,), x=x_obs_torch[i, :],
# C:\Users\u2008181\AppData\Local\Temp\ipykernel_27304\3238161204.py:5: UserWarning: 9.8% of samples drawn with reject_outside_prior=False lie outside the prior support. This may lead to incorrect inference.
#   theta_post_torch = posterior.sample((num_posterior_samples,), x=x_obs_torch[i, :],
# C:\Users\u2008181\AppData\Local\Temp\ipykernel_27304\3238161204.py:5: UserWarning: 34.1% of samples drawn with reject_outside_prior=False lie outside the prior support. This may lead to incorrect inference.
#   theta_post_torch = posterior.sample((num_posterior_samples,), x=x_obs_torch[i, :],
# C:\Users\u2008181\AppData\Local\Temp\ipykernel_27304\3238161204.py:5: UserWarning: 8.4% of samples drawn with reject_outside_prior=False lie outside the prior support. This may lead to incorrect inference.
#   theta_post_torch = posterior.sample((num_posterior_samples,), x=x_obs_torch[i, :],
# C:\Users\u2008181\AppData\Local\Temp\ipykernel_27304\3238161204.py:5: UserWarning: 30.4% of samples drawn with reject_outside_prior=False lie outside the prior support. This may lead to incorrect inference.
#   theta_post_torch = posterior.sample((num_posterior_samples,), x=x_obs_torch[i, :],
# C:\Users\u2008181\AppData\Local\Temp\ipykernel_27304\3238161204.py:5: UserWarning: 17.4% of samples drawn with reject_outside_prior=False lie outside the prior support. This may lead to incorrect inference.
#   theta_post_torch = posterior.sample((num_posterior_samples,), x=x_obs_torch[i, :],
# C:\Users\u2008181\AppData\Local\Temp\ipykernel_27304\3238161204.py:5: UserWarning: 6.5% of samples drawn with reject_outside_prior=False lie outside the prior support. This may lead to incorrect inference.
#   theta_post_torch = posterior.sample((num_posterior_samples,), x=x_obs_torch[i, :],
# C:\Users\u2008181\AppData\Local\Temp\ipykernel_27304\3238161204.py:5: UserWarning: 38.7% of samples drawn with reject_outside_prior=False lie outside the prior support. This may lead to incorrect inference.
#   theta_post_torch = posterior.sample((num_posterior_samples,), x=x_obs_torch[i, :],
# C:\Users\u2008181\AppData\Local\Temp\ipykernel_27304\3238161204.py:5: UserWarning: 11.2% of samples drawn with reject_outside_prior=False lie outside the prior support. This may lead to incorrect inference.
#   theta_post_torch = posterior.sample((num_posterior_samples,), x=x_obs_torch[i, :],
# C:\Users\u2008181\AppData\Local\Temp\ipykernel_27304\3238161204.py:5: UserWarning: 45.8% of samples drawn with reject_outside_prior=False lie outside the prior support. This may lead to incorrect inference.
#   theta_post_torch = posterior.sample((num_posterior_samples,), x=x_obs_torch[i, :],
# C:\Users\u2008181\AppData\Local\Temp\ipykernel_27304\3238161204.py:5: UserWarning: 17.3% of samples drawn with reject_outside_prior=False lie outside the prior support. This may lead to incorrect inference.
#   theta_post_torch = posterior.sample((num_posterior_samples,), x=x_obs_torch[i, :],

# %%
plt.figure(figsize=(12, 8))
sns.set_style('whitegrid')
for i in range(0, x_obs_torch.shape[0]):
    # if i in ignore_indices:
    #     continue
    sns.kdeplot(theta_post[i, :, 0], color='blue', linewidth=0.3, alpha=0.5)
plt.axvline(x=0.077, color='red', linestyle='dashed', label='Ansari and Didelot (2014)')
plt.axvline(x=0.017, color='green', linestyle='dashed', label='Didelot et al. (2010)')
plt.xlabel(r'$\rho_s$')
plt.xlim(0.0, 0.2)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.set_style('whitegrid')
for i in range(0, x_obs_torch.shape[0]):
    # if i in ignore_indices:
    #     continue
    sns.kdeplot(theta_post[i, :, 1], color='blue', linewidth=0.3, alpha=0.5)
plt.axvline(x=0.0528, color='red', linestyle='dashed', label='Ansari and Didelot (2014)')
plt.axvline(x=0.0438, color='green', linestyle='dashed', label='Didelot et al. (2010)')
plt.xlabel(r'$\theta_s$')
plt.xlim(0.0, 0.2)
plt.legend()
plt.show()

# %% [markdown]
# ### Plot bar plots by position

# %%
x_obs_info_table
# Out:
#          Gene_Length  Start_pos  End_pos  Alignment
# Gene_ID
# 0_0             5247      71581    76827       True
# 0_1             5246      76828    82073       True
# 1               4191      67350    71540       True
# 2               2175      28543    30717       True
# 3               2401     142577   144977       True
# ...              ...        ...      ...        ...
# 1214            1363    5190561  5191923       True
# 1215_0          5051    5217306  5222356       True
# 1215_1          5050    5222357  5227406       True
# 1216            6764    5175949  5182712       True
# 1217            3029    5194780  5197808       True
#
# [1277 rows x 4 columns]

# %%
x_obs_info_table['Start_pos'].max()
# Out:
# np.int64(5222357)

# %%
plot_xlim = [0.0, 5222357.0]
samples_x = x_obs_info_table['Start_pos'].values

# %%
posterior_median = np.median(theta_post[:, :, 0], axis=1)
posterior_median.shape, posterior_median.shape
# Out:
# ((1277,), (1277,))

# %%
ci_lower_bounds = np.percentile(theta_post[:, :, 0], 2.5, axis=1)
ci_upper_bounds = np.percentile(theta_post[:, :, 0], 97.5, axis=1)
ci_lower_bounds.shape, ci_upper_bounds.shape
# Out:
# ((1277,), (1277,))

# %%
lower_errors = posterior_median - ci_lower_bounds
upper_errors = ci_upper_bounds - posterior_median
yerr = [lower_errors, upper_errors]

# %%
median_rho = np.median(posterior_median)
median_rho
# Out:
# np.float64(0.00915417866781354)

# %%
plt.figure(figsize=(40, 8))
plt.errorbar(samples_x, posterior_median, yerr=yerr, fmt='o', color='black', 
             ecolor='gray', capsize=4, elinewidth=1.5, markersize=6, alpha=0.3,
             label='Posterior Median ± 95% CI')

plt.title("Posterior Medians with 95% Confidence Intervals for Bacillus Local Recombination Rate", fontsize=14)
plt.xlabel("Position (bp)", fontsize=12)
plt.ylabel(r'$\rho_s$', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.5)
plt.axhline(y=0.077, color='red', linestyle='dashed', label='Ansari and Didelot (2014)')
plt.axhline(y=0.017, color='green', linestyle='dashed', label='Didelot et al. (2010)')
plt.axhline(y=median_rho, color='darkblue', linestyle='dashed', label=r'Median $\rho$ Value')
plt.xlim(plot_xlim)
plt.legend()
plt.show()

# %%
posterior_median_theta = np.median(theta_post[:, :, 1], axis=1)
posterior_median_theta.shape, posterior_median_theta.shape
# Out:
# ((1277,), (1277,))

# %%
ci_lower_bounds_theta = np.percentile(theta_post[:, :, 1], 2.5, axis=1)
ci_upper_bounds_theta = np.percentile(theta_post[:, :, 1], 97.5, axis=1)
ci_lower_bounds_theta.shape, ci_upper_bounds_theta.shape
# Out:
# ((1277,), (1277,))

# %%
lower_errors_theta = posterior_median_theta - ci_lower_bounds_theta
upper_errors_theta = ci_upper_bounds_theta - posterior_median_theta
yerr_theta = [lower_errors_theta, upper_errors_theta]

# %%
median_theta = np.median(posterior_median_theta)
median_theta
# Out:
# np.float64(0.04755576699972153)

# %%
plt.figure(figsize=(40, 8))
plt.errorbar(samples_x, posterior_median_theta, yerr=yerr_theta, fmt='o', color='black', 
             ecolor='gray', capsize=4, elinewidth=1.5, markersize=6, alpha=0.3,
             label='Posterior Median ± 95% CI')

plt.title("Posterior Medians with 95% Confidence Intervals for Bacillus Local Mutation Rate", fontsize=14)
plt.xlabel("Position (bp)", fontsize=12)
plt.ylabel(r'$\theta_s$', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.5)
plt.axhline(y=0.0528, color='red', linestyle='dashed', label='Ansari and Didelot (2014)')
plt.axhline(y=0.0438, color='green', linestyle='dashed', label='Didelot et al. (2010)')
plt.axhline(y=median_theta, color='darkblue', linestyle='dashed', label=r'Median $\theta_s$ Value')
plt.xlim(plot_xlim)
plt.legend()
plt.show()

# %%
samples_l = x_obs_info_table['Gene_Length'].values
samples_l.shape
# Out:
# (1277,)

# %%
posterior_l_median = np.median(theta_post[:, :, 2], axis=1)
posterior_l_median.shape
# Out:
# (1277,)

# %%
ci_lower_bounds_l = np.percentile(theta_post[:, :, 2], 2.5, axis=1)
ci_upper_bounds_l = np.percentile(theta_post[:, :, 2], 97.5, axis=1)
ci_lower_bounds_l.shape, ci_upper_bounds_l.shape
# Out:
# ((1277,), (1277,))

# %%
lower_l_errors = posterior_l_median - ci_lower_bounds_l
upper_l_errors = ci_upper_bounds_l - posterior_l_median
yerr_l = [lower_l_errors, upper_l_errors]

# %%
plt.figure(figsize=(8, 8))
plt.errorbar(samples_l, posterior_l_median, yerr=yerr_l, fmt='o', color='black', 
             ecolor='gray', capsize=4, elinewidth=1.5, markersize=6, 
             label='Posterior Median ± 95% CI')

exact_x = np.linspace(np.min(samples_l), np.max(samples_l), 400)
exact_y = exact_x

plt.title("Posterior Medians with 95% Confidence Intervals for Bacillus Genome Block Length", fontsize=14)
plt.xlabel("True length (bp)", fontsize=12)
plt.ylabel("Estimated length (bp)", fontsize=12)
plt.grid(True, linestyle='--', alpha=0.5)
plt.plot(exact_x, exact_y, color='red', linestyle='dashed')
plt.legend(loc='upper left')
plt.show()

# %%
y_level = 0
gene_starts = np.delete(x_obs_info_table['Start_pos'].values, no_signal_id)
gene_ends   = np.delete(x_obs_info_table['End_pos'].values, no_signal_id)

high_recomb_index = np.where(ci_lower_bounds >= median_rho)[0]
highlight_starts = gene_starts[high_recomb_index]
highlight_ends   = gene_ends[high_recomb_index]

other_genes_index = np.where(ci_lower_bounds < median_rho)[0]
other_starts = gene_starts[other_genes_index]
other_ends   = gene_ends[other_genes_index]

fig, ax = plt.subplots(figsize=(40, 2))

ax.axhline(y=y_level, color='lightgray', linewidth=1, zorder=1)
ax.hlines(y=[y_level] * len(highlight_starts), xmin=highlight_starts, xmax=highlight_ends, 
          color='crimson', linewidth=8, label='Genes with High Recombination', zorder=3)
ax.hlines(y=[y_level] * len(other_starts), xmin=other_starts, xmax=other_ends, 
          color='steelblue', linewidth=4, label='Other Genes', zorder=2)

ax.set_yticks([])
ax.spines['left'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_position('center')

ax.set_ylim(-1, 1)
ax.set_title("Gene Segments with High Recombination rate", pad=20)
ax.legend(loc='upper right')
plt.show()

# %%
gene_starts = np.delete(x_obs_info_table['Start_pos'].values, no_signal_id)
gene_ends = np.delete(x_obs_info_table['End_pos'].values, no_signal_id)
gene_midpoints = (gene_starts + gene_ends) / 2

y = np.asarray(posterior_median)
is_hotspot = ci_lower_bounds >= median_rho
segments = [
    [(start, rate), (end, rate)]
    for start, end, rate in zip(gene_starts, gene_ends, y)
]

colors = np.where(is_hotspot, 'crimson', 'steelblue')
linewidths = np.where(is_hotspot, 3.2, 1.8)
alphas = np.where(is_hotspot, 0.95, 0.55)

fig, ax = plt.subplots(figsize=(40, 8))

# Plot gene intervals efficiently.
lc = LineCollection(
    segments,
    colors=colors,
    linewidths=linewidths,
    alpha=1.0,
    zorder=3,
)
ax.add_collection(lc)

# Add vertical CI bars at each gene midpoint.
# These retain the CI information from your original point/errorbar plot.
ax.vlines(
    gene_midpoints,
    ci_lower_bounds,
    ci_upper_bounds,
    colors='gray',
    linewidth=1.1,
    alpha=0.30,
    zorder=1,
)

# Add small midpoint markers to make exact median locations easier to see.
ax.scatter(
    gene_midpoints[~is_hotspot],
    y[~is_hotspot],
    s=10,
    color='black',
    alpha=0.25,
    zorder=4,
)
ax.scatter(
    gene_midpoints[is_hotspot],
    y[is_hotspot],
    s=22,
    color='crimson',
    edgecolor='black',
    linewidth=0.3,
    alpha=0.95,
    zorder=5,
)

# Reference lines from your original plot.
ax.axhline(
    y=0.077,
    color='red',
    linestyle='dashed',
    linewidth=1.2,
    label='Ansari and Didelot (2014)',
    zorder=2,
)
ax.axhline(
    y=0.017,
    color='green',
    linestyle='dashed',
    linewidth=1.2,
    label='Didelot et al. (2010)',
    zorder=2,
)
ax.axhline(
    y=median_rho,
    color='darkblue',
    linestyle='dashed',
    linewidth=1.2,
    label=r'Median $\rho$ Value',
    zorder=2,
)

# Labels and styling.
ax.set_title(
    'Posterior Medians with 95% Confidence Intervals for Bacillus Local Recombination Rate',
    fontsize=14,
)
ax.set_xlabel('Position (bp)', fontsize=12)
ax.set_ylabel(r'$\rho_s$', fontsize=12)
ax.grid(True, linestyle='--', alpha=0.35)
ax.set_xlim(plot_xlim)

# Set y limits with padding so CI bars are not clipped.
y_min = min(0, np.nanmin(ci_lower_bounds))
y_max = np.nanmax(ci_upper_bounds)
y_pad = 0.05 * (y_max - y_min)
ax.set_ylim(y_min - y_pad, y_max + y_pad)

# Custom legend for interval colors plus reference lines.
hotspot_handle = Line2D(
    [0], [0],
    color='crimson',
    lw=4,
    label=r'Possible hotspot: lower 95% CI $\geq$ median $\rho$',
)
other_handle = Line2D(
    [0], [0],
    color='steelblue',
    lw=4,
    label='Other genes',
)
ci_handle = Line2D(
    [0], [0],
    color='gray',
    lw=1.5,
    alpha=0.5,
    label='95% CI at gene midpoint',
)

handles, labels = ax.get_legend_handles_labels()
ax.legend(
    handles=[hotspot_handle, other_handle, ci_handle] + handles,
    loc='upper right',
    frameon=True,
)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Correlation plots

# %%
df_example = pd.DataFrame(theta_post[0, :, :], columns=[r"$\rho_s$", r"$\theta_s$", "N"])
sns.pairplot(df_example)
plt.suptitle('Pair Plot of NPE-C Posterior Samples given one example observation', fontsize=12, fontweight='bold')
plt.show()

# %%
df_example = pd.DataFrame(theta_post[1, :, :], columns=[r"$\rho_s$", r"$\theta_s$", "N"])
sns.pairplot(df_example)
plt.suptitle('Pair Plot of NPE-C Posterior Samples given one example observation', fontsize=12, fontweight='bold')
plt.show()

# %% [markdown]
# ### Conditional posterior

# %%
theta_dim = prior.event_shape[0]
fixed_dim = 1
fixed_value = median_theta

dims_to_sample = [d for d in range(theta_dim) if d != fixed_dim]

theta_conditional = np.full((x_obs_torch.shape[0], num_posterior_samples, 2), np.nan)
for i in range(x_obs_torch.shape[0]):
    x_o = x_obs_torch[i:i+1]

    potential_fn, theta_transform = posterior_estimator_based_potential(
        density_estimator,
        prior=prior,
        x_o=x_o,
    )

    condition = torch.zeros(theta_dim)
    condition[fixed_dim] = fixed_value

    conditioned_potential_fn, restricted_tf, restricted_prior = conditional_potential(
        potential_fn=potential_fn,
        theta_transform=theta_transform,
        prior=prior,
        condition=condition,
        dims_to_sample=dims_to_sample,
    )

    mcmc_posterior = MCMCPosterior(
        potential_fn=conditioned_potential_fn,
        theta_transform=restricted_tf,
        proposal=restricted_prior,
        method="slice_np_vectorized",
        num_chains=10,
    )

    cond_samples = mcmc_posterior.sample(
        (num_posterior_samples,),
        show_progress_bars=True,
    )

    theta_conditional[i, :, :] = cond_samples.cpu().detach().numpy()
# Out:
# Generating 10 MCMC inits via resample strategy: 100%|██████████| 10/10 [00:01<00:00,  7.26it/s]
# Running vectorized MCMC with 10 chains: 100%|██████████| 3500/3500 [00:59<00:00, 58.51it/s]
# Generating 10 MCMC inits via resample strategy: 100%|██████████| 10/10 [00:01<00:00,  9.04it/s]
# Running vectorized MCMC with 10 chains: 100%|██████████| 3500/3500 [01:00<00:00, 58.25it/s]
# Generating 10 MCMC inits via resample strategy: 100%|██████████| 10/10 [00:01<00:00,  8.45it/s]
# Running vectorized MCMC with 10 chains: 100%|██████████| 3500/3500 [01:09<00:00, 50.42it/s]
# Generating 10 MCMC inits via resample strategy: 100%|██████████| 10/10 [00:01<00:00,  7.91it/s]
# Running vectorized MCMC with 10 chains:   0%|          | 0/3500 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[105], line 36
#      20 conditioned_potential_fn, restricted_tf, restricted_prior = conditional_potential(
#      21     potential_fn=potential_fn,
#      22     theta_transform=theta_transform,
#    (...)     25     dims_to_sample=dims_to_sample,
#      26 )
#      28 mcmc_posterior = MCMCPosterior(
#      29     potential_fn=conditioned_potential_fn,
#      30     theta_transform=restricted_tf,
#    (...)     33     num_chains=10,
#      34 )
# ---> 36 cond_samples = mcmc_posterior.sample(
#      37     (num_posterior_samples,),
#      38     show_progress_bars=True,
#      39 )
#      41 theta_conditional[i, :, :] = cond_samples.cpu().detach().numpy()
#
# File c:\Users\u2008181\likelihood-free\sbi_env\Lib\site-packages\sbi\inference\posteriors\mcmc_posterior.py:323, in MCMCPosterior.sample(self, sample_shape, x, method, thin, warmup_steps, num_chains, init_strategy, init_strategy_parameters, num_workers, mp_context, show_progress_bars)
#     321 with torch.set_grad_enabled(track_gradients):
#     322     if method in ("slice_np", "slice_np_vectorized"):
# --> 323         transformed_samples = self._slice_np_mcmc(
#     324             num_samples=num_samples,
#     325             potential_function=self.potential_,
#     326             initial_params=initial_params,
#     327             thin=thin,  # type: ignore
#     328             warmup_steps=warmup_steps,  # type: ignore
#     329             vectorized=(method == "slice_np_vectorized"),
#     330             interchangeable_chains=True,
#     331             num_workers=num_workers,
#     332             show_progress_bars=show_progress_bars,
#     333         )
#     334     elif method in ("hmc_pyro", "nuts_pyro"):
#     335         transformed_samples = self._pyro_mcmc(
#     336             num_samples=num_samples,
#     337             potential_function=self.potential_,
#    (...)    344             mp_context=mp_context,
#     345         )
#
# File c:\Users\u2008181\likelihood-free\sbi_env\Lib\site-packages\sbi\inference\posteriors\mcmc_posterior.py:768, in MCMCPosterior._slice_np_mcmc(self, num_samples, potential_function, initial_params, thin, warmup_steps, vectorized, interchangeable_chains, num_workers, init_width, show_progress_bars)
#     766 num_samples_ = ceil((num_samples * thin) / num_chains)
#     767 # Run mcmc including warmup
# --> 768 samples = posterior_sampler.run(warmup_ + num_samples_)
#     769 samples = samples[:, warmup_steps:, :]  # discard warmup steps
#     770 samples = torch.from_numpy(samples)  # chains x samples x dim
#
# File c:\Users\u2008181\likelihood-free\sbi_env\Lib\site-packages\sbi\samplers\mcmc\slice_numpy.py:462, in SliceSamplerVectorized.run(self, num_samples)
#     455         sc["next_param"] = np.concatenate([
#     456             sc["x"][: sc["order"][sc["i"]]],
#     457             [sc["cxi"]],
#     458             sc["x"][sc["order"][sc["i"]] + 1 :],
#     459         ])
#     461 params = np.stack([sc["next_param"] for sc in self.state.values()])
# --> 462 log_probs = self._log_prob_fn(params)
#     464 for c in range(self.num_chains):
#     465     sc = self.state[c]
#
# File c:\Users\u2008181\likelihood-free\sbi_env\Lib\site-packages\sbi\inference\posteriors\mcmc_posterior.py:753, in MCMCPosterior._slice_np_mcmc.<locals>.multi_obs_potential(params)
#     751 def multi_obs_potential(params):
#     752     # Params are of shape (num_chains * num_obs, event).
# --> 753     all_potentials = potential_function(params)  # Shape: (num_chains, num_obs)
#     754     return all_potentials.flatten()
#
# File c:\Users\u2008181\likelihood-free\sbi_env\Lib\site-packages\sbi\utils\potentialutils.py:44, in transformed_potential(theta, potential_fn, theta_transform, device, track_gradients)
#      41 theta = theta_transform.inv(transformed_theta)  # type: ignore
#      42 log_abs_det = theta_transform.log_abs_det_jacobian(theta, transformed_theta)
# ---> 44 posterior_potential = potential_fn(theta, track_gradients=track_gradients)
#      45 posterior_potential_transformed = posterior_potential.to(device) - log_abs_det.to(
#      46     device
#      47 )
#      48 return posterior_potential_transformed
#
# File c:\Users\u2008181\likelihood-free\sbi_env\Lib\site-packages\sbi\utils\conditional_density_utils.py:399, in ConditionedPotential.__call__(self, theta, track_gradients)
#     396 theta_condition = theta_condition.repeat(theta_.shape[0], 1)
#     397 theta_condition[:, self.dims_to_sample] = theta_
# --> 399 return self.potential_fn(theta_condition, track_gradients=track_gradients)
#
# File c:\Users\u2008181\likelihood-free\sbi_env\Lib\site-packages\sbi\inference\potentials\posterior_based_potential.py:174, in PosteriorBasedPotential.__call__(self, theta, track_gradients)
#     167 if x_batch_size == 1:
#     168     # If a single `x` is passed (i.e. batchsize==1), we squeeze
#     169     # the batch dimension of the log-prob with `.squeeze(dim=1)`.
#     170     theta = reshape_to_sample_batch_event(
#     171         theta, event_shape=theta.shape[1:], leading_is_sample=True
#     172     )
# --> 174     posterior_log_prob = self.posterior_estimator.log_prob(
#     175         theta, condition=x
#     176     )
#     177     posterior_log_prob = posterior_log_prob.squeeze(1)
#     178 else:
#     179     # If multiple `x` are passed, we return the log-probs for each
#     180     # (x,theta) pair, and do not squeeze the batch dimension.
#
# File c:\Users\u2008181\likelihood-free\sbi_env\Lib\site-packages\sbi\neural_nets\estimators\nflows_flow.py:96, in NFlowsFlow.log_prob(self, input, condition)
#      93 input = input.reshape(sample_dim * batch_dim, -1)
#      94 condition = condition.reshape(sample_dim * batch_dim, *self.condition_shape)
# ---> 96 log_probs = self.net.log_prob(input, context=condition)
#      97 return log_probs.reshape(sample_dim, batch_dim)
#
# File c:\Users\u2008181\likelihood-free\sbi_env\Lib\site-packages\nflows\distributions\base.py:40, in Distribution.log_prob(self, inputs, context)
#      36     if inputs.shape[0] != context.shape[0]:
#      37         raise ValueError(
#      38             "Number of input items must be equal to number of context items."
#      39         )
# ---> 40 return self._log_prob(inputs, context)
#
# File c:\Users\u2008181\likelihood-free\sbi_env\Lib\site-packages\nflows\flows\base.py:39, in Flow._log_prob(self, inputs, context)
#      37 def _log_prob(self, inputs, context):
#      38     embedded_context = self._embedding_net(context)
# ---> 39     noise, logabsdet = self._transform(inputs, context=embedded_context)
#      40     log_prob = self._distribution.log_prob(noise, context=embedded_context)
#      41     return log_prob + logabsdet
#
# File c:\Users\u2008181\likelihood-free\sbi_env\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\u2008181\likelihood-free\sbi_env\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\u2008181\likelihood-free\sbi_env\Lib\site-packages\nflows\transforms\base.py:56, in CompositeTransform.forward(self, inputs, context)
#      54 def forward(self, inputs, context=None):
#      55     funcs = self._transforms
# ---> 56     return self._cascade(inputs, funcs, context)
#
# File c:\Users\u2008181\likelihood-free\sbi_env\Lib\site-packages\nflows\transforms\base.py:50, in CompositeTransform._cascade(inputs, funcs, context)
#      48 total_logabsdet = inputs.new_zeros(batch_size)
#      49 for func in funcs:
# ---> 50     outputs, logabsdet = func(outputs, context)
#      51     total_logabsdet += logabsdet
#      52 return outputs, total_logabsdet
#
# File c:\Users\u2008181\likelihood-free\sbi_env\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\u2008181\likelihood-free\sbi_env\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\u2008181\likelihood-free\sbi_env\Lib\site-packages\nflows\transforms\coupling.py:83, in CouplingTransform.forward(self, inputs, context)
#      80 identity_split = inputs[:, self.identity_features, ...]
#      81 transform_split = inputs[:, self.transform_features, ...]
# ---> 83 transform_params = self.transform_net(identity_split, context)
#      84 transform_split, logabsdet = self._coupling_transform_forward(
#      85     inputs=transform_split, transform_params=transform_params
#      86 )
#      88 if self.unconditional_transform is not None:
#
# File c:\Users\u2008181\likelihood-free\sbi_env\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\u2008181\likelihood-free\sbi_env\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\u2008181\likelihood-free\sbi_env\Lib\site-packages\nflows\nn\nets\resnet.py:98, in ResidualNet.forward(self, inputs, context)
#      96     temps = self.initial_layer(torch.cat((inputs, context), dim=1))
#      97 for block in self.blocks:
# ---> 98     temps = block(temps, context=context)
#      99 outputs = self.final_layer(temps)
#     100 return outputs
#
# File c:\Users\u2008181\likelihood-free\sbi_env\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\u2008181\likelihood-free\sbi_env\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\u2008181\likelihood-free\sbi_env\Lib\site-packages\nflows\nn\nets\resnet.py:44, in ResidualBlock.forward(self, inputs, context)
#      42     temps = self.batch_norm_layers[0](temps)
#      43 temps = self.activation(temps)
# ---> 44 temps = self.linear_layers[0](temps)
#      45 if self.use_batch_norm:
#      46     temps = self.batch_norm_layers[1](temps)
#
# File c:\Users\u2008181\likelihood-free\sbi_env\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\u2008181\likelihood-free\sbi_env\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\u2008181\likelihood-free\sbi_env\Lib\site-packages\torch\nn\modules\linear.py:125, in Linear.forward(self, input)
#     124 def forward(self, input: Tensor) -> Tensor:
# --> 125     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:
