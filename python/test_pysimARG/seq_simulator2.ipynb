# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sys
sys.path.append('../../pysimARG')
from clonal_genealogy import ClonalTree
from ClonalOrigin_nodes import ClonalOrigin_nodes
from ClonalOrigin_ARG import ARG
from add_mutation import add_mutation
from G3_test import G3_test
from LD_r import LD_r
from homoplasy_index import homoplasy_index
from ClonalOrigin_seq_sim import ClonalOrigin_seq_sim

# %% [markdown]
# ## Check inputs

# %%
tree1 = ClonalTree(n=15)

# %%
print(tree1)
# Out:
# ClonalTree(n=15)

# %%
tree1.edge
# Out:
# array([[1.60000000e+01, 1.00000000e+01, 1.21138030e-03],
#        [1.60000000e+01, 1.50000000e+01, 1.21138030e-03],
#        [1.70000000e+01, 8.00000000e+00, 4.36121724e-03],
#        [1.70000000e+01, 4.00000000e+00, 4.36121724e-03],
#        [1.80000000e+01, 1.10000000e+01, 5.27280822e-02],
#        [1.80000000e+01, 1.40000000e+01, 5.27280822e-02],
#        [1.90000000e+01, 7.00000000e+00, 6.99823525e-02],
#        [1.90000000e+01, 1.30000000e+01, 6.99823525e-02],
#        [2.00000000e+01, 1.20000000e+01, 7.59683047e-02],
#        [2.00000000e+01, 3.00000000e+00, 7.59683047e-02],
#        [2.10000000e+01, 2.00000000e+00, 9.17698694e-02],
#        [2.10000000e+01, 1.70000000e+01, 8.74086522e-02],
#        [2.20000000e+01, 1.60000000e+01, 1.36267346e-01],
#        [2.20000000e+01, 1.90000000e+01, 6.74963739e-02],
#        [2.30000000e+01, 5.00000000e+00, 1.71522026e-01],
#        [2.30000000e+01, 2.10000000e+01, 7.97521568e-02],
#        [2.40000000e+01, 9.00000000e+00, 2.13636460e-01],
#        [2.40000000e+01, 2.20000000e+01, 7.61577340e-02],
#        [2.50000000e+01, 2.00000000e+01, 2.04950041e-01],
#        [2.50000000e+01, 1.80000000e+01, 2.28190264e-01],
#        [2.60000000e+01, 2.50000000e+01, 6.95592344e-03],
#        [2.60000000e+01, 1.00000000e+00, 2.87874269e-01],
#        [2.70000000e+01, 2.30000000e+01, 1.41811300e-01],
#        [2.70000000e+01, 6.00000000e+00, 3.13333326e-01],
#        [2.80000000e+01, 2.60000000e+01, 3.53633557e-02],
#        [2.80000000e+01, 2.70000000e+01, 9.90429899e-03],
#        [2.90000000e+01, 2.80000000e+01, 1.09369372e+00],
#        [2.90000000e+01, 2.40000000e+01, 1.20329489e+00]])

# %%
tree1.node_height
# Out:
# array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.21138030e-03,
#        4.36121724e-03, 5.27280822e-02, 6.99823525e-02, 7.59683047e-02,
#        9.17698694e-02, 1.37478726e-01, 1.71522026e-01, 2.13636460e-01,
#        2.80918346e-01, 2.87874269e-01, 3.13333326e-01, 3.23237625e-01,
#        1.41693135e+00])

# %% [markdown]
# ## Seq function with long chain

# %%
L = 1000000

# %%
ARG_1 = ARG(tree1, 0.5, L, 5.0, L, "seq")
ARG_1.edge
