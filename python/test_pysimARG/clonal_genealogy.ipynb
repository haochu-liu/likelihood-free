# %%
import numpy as np
import sys
sys.path.append('../../pysimARG')
import clonal_genealogy

# %%
clonal_genealogy_test = clonal_genealogy.ClonalTree(n=10)

# %%
print(clonal_genealogy_test)
# Out:
# ClonalTree(n=10)

# %%
np.int64(clonal_genealogy_test.edge[:, range(2)])
# Out:
# array([[10,  5],
#        [10,  4],
#        [11,  6],
#        [11,  9],
#        [12,  0],
#        [12,  8],
#        [13, 10],
#        [13,  2],
#        [14,  3],
#        [14, 13],
#        [15,  7],
#        [15,  1],
#        [16, 12],
#        [16, 11],
#        [17, 16],
#        [17, 15],
#        [18, 14],
#        [18, 17]])
