# %%
import numpy as np

# %%
type = "pai"

# %%
if not (type == "seq" or type == "pair"):
    print("`type` must be a string equal to 'pair' or 'seq'.")
else:
    print(0)
# Out:
# `type` must be a string equal to 'pair' or 'seq'.

# %%
def calculate_discount(price, discount_rate):
    return price - (price * discount_rate)
